# %%
from thirdai import licensing 

licensing.activate("8D770F-CAD577-709DB7-AF4F3F-3CE07B-V3")

from thirdai.neural_db import parsing_utils
from thirdai import neural_db as ndb

db = ndb.NeuralDB(user_id="my_user")
db.from_scratch()

# %%
valid_url_data = parsing_utils.recursive_url_scrape(base_url="https://www.infineon.com", max_crawl_depth=1)
# Out:
# crawl depth: 1
# Adding https://www.infineon.com
# Adding https://www.infineon.com/cms/en/
# Adding https://www.infineon.com/cms/en/product/
# Adding https://www.infineon.com/cms/en/applications/
# Adding https://www.infineon.com/cms/en/design-support/
# Adding https://www.infineon.com/cms/en/community
# Adding https://www.infineon.com/cms/en/about-infineon/
# Adding https://www.infineon.com/cms/en/careers/
# Adding https://www.infineon.com/cms/en/product/promopages/newsletter-registration/
# Adding https://www.infineon.com/cms/en/about-infineon/company/contacts/
# Adding https://www.infineon.com/cms/en/product/promopages/where-to-buy/
# Adding https://www.infineon.com/cms/cn/
# Adding https://www.infineon.com/cms/de/
# Adding https://www.infineon.com/cms/jp/
# Adding https://www.infineon.com/cms/en/cart/
# Adding https://www.infineon.com/cms/en/about-infineon/company/
# Adding https://www.infineon.com/cms/en/about-infineon/company/our-divisions/
# ...

# %%
documents = []
for url, response in valid_url_data:
    try:
        documents.append(ndb.URL(url, response))
    except:
        continue

# %%
source_ids = db.insert(documents, train=True)
# Out:
# loading data | source 'Documents:
# https://www.infineon.com/cms/en/about-infineon/
# https://www.infineon.com/cms/en/about-infineon/make-iot-work/
# https://www.infineon.com/cms/en/product/sensor/pressure-sensors/
# https://www.infineon.com/cms/en/product/technology/.xt/
# https://www.infineon.com/cms/en/applications/security-solutions/ticketing-solutions/
# https://www.infineon.com/cms/en/about-infineon/press/press-kit/
# https://www.infineon.com/cms/en/product/search/opn/orderable-part-number-opn-translation-table/
# https://www.infineon.com/cms/en/applications/industrial/traction/
# https://www.infineon.com/#collapse-98163ef2-2840-11e4-9059-556353e4878f-application-8-3
# https://www.infineon.com/cms/en/product/power/gate-driver-ics/
# https://www.infineon.com/cms/en/applications/automotive/
# https://www.infineon.com/cms/en/applications/space-applications/
# https://www.infineon.com/cms/en/design-support/software/code-examples/psoc-6-code-examples-for-modustoolbox/
# ...

# %% [markdown]
# # Query With NeuralDB

# %%
import openai

openai.api_key = "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"

# %%
from newutils import get_capabilities

task = "Given the strategy statement provide a set of capabilities that an organization would need to meet."

context = """
Strategy Statement: "...make a major investment in the expansion of our site in 
Dresden (Germany). Structural demand for semiconductor solutions will continue 
to rise, driven by decarbonization and digitalization. With the construction of 
an additional 300-millimeter module in Dresden, we could achieve growth in the 
data center, automotive and IoT application areas with analog mixed-signal 
products and power semiconductors. We are planning to invest €5 billion here....
A modular, scalable design would reduce the investment risk. Production at the 
new plant could start in autumn 2026, creating up to 1,000 new high-quality jobs.
If the factory is developed to its full extent, we expect it to have the 
potential to generate additional annual revenue that matches the total investment."
"""

response = get_capabilities(db, task, context)

# %%
for capability in response.split("\n\n"):
    print(capability)
# Out:
# Revised set of capabilities:
# 1. Manufacturing and Operations: The organization would need strong manufacturing and operations capabilities to manufacture IGBTs and diodes for Semikron Danfoss at its sites in Dresden, Germany, and Kulim, Malaysia. This would involve production planning, process optimization, quality control, and supply chain management.
# 2. Product Development and Engineering: The organization would need capabilities in product development and engineering to design and develop automotive power modules in Nuremberg and Flensburg in Germany, Utica in the US, and Nanjing in China. This would involve expertise in semiconductor design, prototyping, and testing.
# 3. Market Analysis and Forecasting: The organization would need the capability to analyze and forecast market demand for power systems and IoT solutions in the context of decarbonization and digitalization. This would involve market research, competitive analysis, and trend analysis.
# ...

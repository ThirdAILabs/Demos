# %% [markdown]
# # Distributed Model inference using ThirdAI
#
# This notebook demonstrates how to do distributed model inference using ThirdAI with ThirdAI's UDT and amazon_polarity dataset.
#
# The guide consists of the following sections:
# * Import all necessary libraries.
# * Prepare a trained ThirdAI UDT model for inference.
# * Run model inference using Pandas UDF
#
# **Note:**
# * This notebook should be running on a Databricks cluster.
# * Make sure to add thirdai's license to `/dbfs/mnt/`. For getting license contact: https://www.thirdai.com/try-bolt/

# %% [markdown]
# ## Import all necessary libraries

# %%
# !python3 -m pip install --upgrade pip
# !python3 -m pip install thirdai
# !python3 -m pip install datasets
# !python3 -m pip install utils
# Out:
# Requirement already satisfied: pip in /local_disk0/.ephemeral_nfs/envs/pythonEnv-a6a543dd-77ff-4261-800d-dbd325f81881/lib/python3.9/site-packages (21.2.4)
# Collecting pip
#   Downloading pip-22.3.1-py3-none-any.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 16.0 MB/s
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 21.2.4
#     Uninstalling pip-21.2.4:
#       Successfully uninstalled pip-21.2.4
# Successfully installed pip-22.3.1
# Collecting thirdai
#   Downloading thirdai-0.5.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 15.7 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /databricks/python3/lib/python3.9/site-packages (from thirdai) (1.3.4)
# Requirement already satisfied: numpy in /databricks/python3/lib/python3.9/site-packages (from thirdai) (1.20.3)
# Requirement already satisfied: typing-extensions in /databricks/python3/lib/python3.9/site-packages (from thirdai) (3.10.0.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /databricks/python3/lib/python3.9/site-packages (from pandas->thirdai) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /databricks/python3/lib/python3.9/site-packages (from pandas->thirdai) (2021.3)
# Requirement already satisfied: six>=1.5 in /databricks/python3/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas->thirdai) (1.16.0)
# Installing collected packages: thirdai
# Successfully installed thirdai-0.5.3
# Collecting datasets
#   Downloading datasets-2.7.0-py3-none-any.whl (451 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 451.6/451.6 kB 4.6 MB/s eta 0:00:00
# Collecting dill<0.3.7
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 546.3 kB/s eta 0:00:00
# Collecting aiohttp
#   Downloading aiohttp-3.8.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 6.5 MB/s eta 0:00:00
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (661 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 661.8/661.8 kB 47.6 MB/s eta 0:00:00
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: numpy>=1.17 in /databricks/python3/lib/python3.9/site-packages (from datasets) (1.20.3)
# Requirement already satisfied: pandas in /databricks/python3/lib/python3.9/site-packages (from datasets) (1.3.4)
# Collecting huggingface-hub<1.0.0,>=0.2.0
#   Downloading huggingface_hub-0.11.0-py3-none-any.whl (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.1/182.1 kB 25.9 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=6.0.0 in /databricks/python3/lib/python3.9/site-packages (from datasets) (7.0.0)
# Requirement already satisfied: packaging in /databricks/python3/lib/python3.9/site-packages (from datasets) (21.0)
# Requirement already satisfied: requests>=2.19.0 in /databricks/python3/lib/python3.9/site-packages (from datasets) (2.26.0)
# Collecting tqdm>=4.62.1
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 14.7 MB/s eta 0:00:00
# Collecting fsspec[http]>=2021.11.1
#   Downloading fsspec-2022.11.0-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.5/139.5 kB 15.1 MB/s eta 0:00:00
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 kB 18.7 MB/s eta 0:00:00
# Collecting xxhash
#   Downloading xxhash-3.1.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.0/212.0 kB 20.0 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 21.5 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /databricks/python3/lib/python3.9/site-packages (from aiohttp->datasets) (2.0.4)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 kB 26.0 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /databricks/python3/lib/python3.9/site-packages (from aiohttp->datasets) (21.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /databricks/python3/lib/python3.9/site-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (3.10.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (3.8.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /databricks/python3/lib/python3.9/site-packages (from packaging->datasets) (3.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /databricks/python3/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (2021.10.8)
# Requirement already satisfied: python-dateutil>=2.7.3 in /databricks/python3/lib/python3.9/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /databricks/python3/lib/python3.9/site-packages (from pandas->datasets) (2021.3)
# Requirement already satisfied: six>=1.5 in /databricks/python3/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, tqdm, pyyaml, multidict, fsspec, frozenlist, dill, async-timeout, yarl, responses, multiprocess, huggingface-hub, aiosignal, aiohttp, datasets
# Successfully installed aiohttp-3.8.3 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.7.0 dill-0.3.6 frozenlist-1.3.3 fsspec-2022.11.0 huggingface-hub-0.11.0 multidict-6.0.2 multiprocess-0.70.14 pyyaml-6.0 responses-0.18.0 tqdm-4.64.1 xxhash-3.1.0 yarl-1.8.1
# Collecting utils
#   Downloading utils-1.0.1-py2.py3-none-any.whl (21 kB)
# Installing collected packages: utils
# Successfully installed utils-1.0.1

# %%
import pandas as pd
from datasets import load_dataset
import numpy as np

import thirdai
from thirdai import bolt

from pyspark.sql import SparkSession
from pyspark.sql.types import *
from pyspark.sql.types import StringType, ArrayType, FloatType
from pyspark.sql.functions import col, pandas_udf, PandasUDFType

# %% [markdown]
# ## Prepare a trained ThirdAI UDT model for inference

# %% [markdown]
# Setting ThirdAI's license path here. For getting license contact: https://www.thirdai.com/try-bolt/

# %%
thirdai.set_thirdai_license_path("/dbfs/mnt/license.serialized")

# %% [markdown]
# Loading Amazon Polarity Dataset

# %%
def load_data(output_filename, split, return_inference_batch=False):
    data = load_dataset('amazon_polarity')
    
    df = pd.DataFrame(data[split])
    df = df[['title', 'label']]    
    df.to_csv(output_filename, index=False, sep='\t')
    

train_filename = "/dbfs/mnt/amazon_polarity_train.csv"
test_filename = "/dbfs/mnt/amazon_polarity_test.csv"

load_data(train_filename, split='train')
load_data(test_filename, split='test', return_inference_batch=False)
# Out:
# Downloading builder script:   0%|          | 0.00/4.11k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/1.68k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/6.66k [00:00<?, ?B/s]
# Downloading and preparing dataset amazon_polarity/amazon_polarity to /root/.cache/huggingface/datasets/amazon_polarity/amazon_polarity/3.0.0/a27b32b7e7b88eb274a8fa8ba0f654f1fe998a87c22547557317793b5d2772dc...
# Downloading data:   0%|          | 0.00/688M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/3600000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/400000 [00:00<?, ? examples/s]
# Dataset amazon_polarity downloaded and prepared to /root/.cache/huggingface/datasets/amazon_polarity/amazon_polarity/3.0.0/a27b32b7e7b88eb274a8fa8ba0f654f1fe998a87c22547557317793b5d2772dc. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]
# WARNING:datasets.builder:Found cached dataset amazon_polarity (/root/.cache/huggingface/datasets/amazon_polarity/amazon_polarity/3.0.0/a27b32b7e7b88eb274a8fa8ba0f654f1fe998a87c22547557317793b5d2772dc)
#   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# Training, Evaluating and Saving a Bolt's UDT Model.

# %%
model = bolt.UniversalDeepTransformer(
    data_types={
        "title": bolt.types.text(),
        "label": bolt.types.categorical()
    },
    n_target_classes=2,
    target="label",
    delimiter='\t',
)

# %%
train_config = (bolt.TrainConfig(epochs=1, learning_rate=0.01)
                    .with_metrics(["categorical_accuracy"]))

model.train(train_filename, train_config)
# Out:
# Loading vectors from '/dbfs/mnt/amazon_polarity_train.csv'
# Loaded 3600000 vectors from '/dbfs/mnt/amazon_polarity_train.csv' in 6 seconds.
# train epoch 0:
#
# [==================================================] 100%
#
# train | epoch 0 | updates 1758 | {categorical_accuracy: 0.84207} | batches 1758 | time 205s | complete

# %%
eval_config = (bolt.EvalConfig()
                   .with_metrics(["categorical_accuracy"]))

model.evaluate(test_filename, eval_config);
# Out:
# Loading vectors from '/dbfs/mnt/amazon_polarity_test.csv'
# Loaded 400000 vectors from '/dbfs/mnt/amazon_polarity_test.csv' in 0 seconds.
# test:
#
# [==================================================] 100%
#
# predict | epoch 1 | updates 1758 | {categorical_accuracy: 0.855015} | batches 196 | time 7624ms

# %%
save_location = "/dbfs/mnt/sentiment_analysis.model"
model.save(save_location)

# %% [markdown]
# ## Run model inference using Pandas UDF

# %%
#Enable Arrow support
spark.conf.set("spark.sql.execution.arrow.enabled", "true")
spark.conf.set("spark.sql.execution.arrow.maxRecordsPerBatch", "64")

# %% [markdown]
# Load the data into Spark Dataframes.

# %%
test_datasets = "dbfs:/mnt/amazon_polarity_test.csv"
df = spark.read.option("header",True).option("sep", "\t").csv(test_datasets).repartition(6)

# %% [markdown]
# Define the function for model inference.

# %%
@pandas_udf("long")
def predict_batch_udf(batch_iter: pd.Series) -> pd.Series:
    thirdai.set_thirdai_license_path("/dbfs/mnt/license.serialized")
    save_location = "/dbfs/mnt/sentiment_analysis.model"
    model = bolt.UniversalDeepTransformer.load(save_location, "classifier")
    preds = []
    for i in batch_iter:
        pred = model.predict({"title":i})
        class_name = model.class_name(pred.argmax())
        preds.append(int(class_name))
    return pd.Series(preds)

# %% [markdown]
# Run the model inference and get the predictions

# %%
predictions_df = df.select(predict_batch_udf("title"))
predictions_df.head(10)
# Out:
# Out[26]: [Row(predict_batch_udf(title)=0),
#  Row(predict_batch_udf(title)=0),
#  Row(predict_batch_udf(title)=1),
#  Row(predict_batch_udf(title)=0),
#  Row(predict_batch_udf(title)=1),
#  Row(predict_batch_udf(title)=1),
#  Row(predict_batch_udf(title)=0),
#  Row(predict_batch_udf(title)=0),
#  Row(predict_batch_udf(title)=1),
#  Row(predict_batch_udf(title)=0)]
